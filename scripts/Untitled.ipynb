# %%
from board import Board
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt

# %%
chess_board = Board(423, 320, 240, 1, 83, 445, 100, 464)
print(chess_board.image_to_absolute(44.7, 378, 306))
# Out:
# (371.8709219858156, 299.02553191489363)

# %%
points = [[133,159],[236,209],[131,358],[281,406]]

# %%
image = '/home/david/tesimg2.png'
img = cv2.imread(image)

# %%
p = points[0]
_ = cv2.circle(img,(p[0], p[1]), 5, (255,0,0), 2)
mp = chess_board.image_to_absolute(37.5, p[0], p[1])
_ = cv2.circle(img,(int(mp[0]), int(mp[1])), 5, (0,255,0), 2)

p = points[1]
_ = cv2.circle(img,(p[0], p[1]), 5, (255,0,0), 2)
mp = chess_board.image_to_absolute(27.8, p[0], p[1])
_ = cv2.circle(img,(int(mp[0]), int(mp[1])), 5, (0,255,0), 2)

p = points[2]
_ = cv2.circle(img,(p[0], p[1]), 5, (255,0,0), 2)
mp = chess_board.image_to_absolute(38, p[0], p[1])
_ = cv2.circle(img,(int(mp[0]), int(mp[1])), 5, (0,255,0), 2)

p = points[3]
_ = cv2.circle(img,(p[0], p[1]), 5, (255,0,0), 2)
mp = chess_board.image_to_absolute(34.4, p[0], p[1])
_ = cv2.circle(img,(int(mp[0]), int(mp[1])), 5, (0,255,0), 2)

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams['figure.figsize'] = [12, 6]
plt.imshow(img)
