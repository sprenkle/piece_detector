# %%
from board import Board
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt

# %%
chess_board = Board(423, 320, 240, 1.4558, 83, 445, 100, 464)
print(chess_board.image_to_absolute(44.7, 378, 306))
# Out:
# (369.0772882269504, 295.8465693617021)

# %%
points = [[133,159],[236,209],[377,306],[131,358],[281,406]]

# %%
image = '/home/david/tesimg2.png'
img = cv2.imread(image)

# %%
for p in points:
    print(p)
    cv2.circle(img,(p[0], p[1]), 5, (255,0,0), 2)
# Out:
# [133, 159]
# [236, 209]
# [377, 306]
# [131, 358]
# [281, 406]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7e33679094ef> in <module>
#       2     print(p)
#       3
# ----> 4 cv2.circle(img,(center_x, center_y), 5, (255,0,0), 2)
#
# NameError: name 'center_x' is not defined

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams['figure.figsize'] = [12, 6]
plt.imshow(img)
